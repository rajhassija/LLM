# %%
from rag_framework import LoadDocs

if __name__ == "__main__":
    ingestdoc = LoadDocs()
    directory_path = r'c:\Users\rajes\OneDrive\Documents\GitHub\rajpersonal\Gemini\pdf'
    chroma_dir = r'C:\tbd\data\chroma_google_db2'
    model= "gemini-1.5-pro"
    # model="deepseek-r1:8b"
    ingestdoc.process_and_store_pdfs(directory_path, chroma_dir, model)
# Out:
# Processing BCA Dog Owner Registration Form1235.pdf...
# Book c:\Users\rajes\OneDrive\Documents\GitHub\rajpersonal\Gemini\pdf\BCA Dog Owner Registration Form1235.pdf successfully loaded and recorded.
# Processing BCA Fireplace NonUse Form 2024_20252325.pdf...
# Book c:\Users\rajes\OneDrive\Documents\GitHub\rajpersonal\Gemini\pdf\BCA Fireplace NonUse Form 2024_20252325.pdf successfully loaded and recorded.
# Processing BCA Rental Acknowledgement Form.pdf...
# Book c:\Users\rajes\OneDrive\Documents\GitHub\rajpersonal\Gemini\pdf\BCA Rental Acknowledgement Form.pdf successfully loaded and recorded.
# Processing BCA Welcome Letter 2023.pdf...
# Book c:\Users\rajes\OneDrive\Documents\GitHub\rajpersonal\Gemini\pdf\BCA Welcome Letter 2023.pdf successfully loaded and recorded.
# Processing The Birches Rules and Regulations.pdf...
# Book c:\Users\rajes\OneDrive\Documents\GitHub\rajpersonal\Gemini\pdf\The Birches Rules and Regulations.pdf successfully loaded and recorded.
# ...

# %%
# from rag_framework import LoadDocs

# if __name__ == "__main__":
#     chroma_dir = r'C:\Users\rajes\OneDrive\Documents\GitHub\rajpersonal\Gemini\data\chroma_google_db'
#     query = 'what info is needed for firplace use ?'
#     llmoutput = LoadDocs(chroma_dir,query)
#     output = llmoutput.LlmSynthesis.generate_synthesis(chroma_dir,query)
#     print(output)

from rag_framework import LlmSynthesis

if __name__ == "__main__":
    chroma_dir = r'C:\tbd\data\chroma_google_db2'
    # query = 'what are rules and regulations? provide details for each category?'
    query = 'what are instructions for fireplace use?'
    model="gemini-1.5-pro"
    # model="deepseek-r1:8b"
    llmoutput = LlmSynthesis(chroma_dir, query, model)
    output = llmoutput.generate_synthesis(chroma_dir,query, model)
    print(output)
# Out:
# Once yearly, between May 1 and November 1, all units having a fireplace, whether or not having been used since the previous inspection period, shall be inspected at Unit Owner cost. The Owner is responsible for coordinating such inspection, and for providing proof of completion by forwarding a copy of the inspection report to the managing agent, to be received not later than November 1.
#
# If you have a gas insert or if you will not use the fireplace, you MUST complete the Fireplace Non-Use statement.  Any Unit failing to provide such proof of inspection shall be assessed a fine equal to $25.00 per month until such proof of inspection has been received by the managing agent.
