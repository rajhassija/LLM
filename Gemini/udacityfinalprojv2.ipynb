# %%
# importing the required libraries

import os
from dotenv import load_dotenv
import getpass
import pandas as pd
import numpy as np
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.llms import OpenAI
from langchain.schema import AIMessage, HumanMessage, SystemMessage
from langchain.memory import ConversationSummaryMemory, ConversationBufferMemory, CombinedMemory
from langchain.chains import ConversationChain
from typing import Any, Dict, Optional, Tuple
from langchain.memory import ChatMessageHistory

from langchain.chains import ConversationChain


#initializing the google api key
os.environ['GOOGLE_API_KEY'] = 'AIzaSyDG8Hh3JEAwWKdXz5j6yjJL2GKOlUy_7es'

#initializing the google llm model
llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-pro",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2 #,     # other params...
)
#setting the embeddings model
embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")

# %% [markdown]
# Below we will create a fancy prompt and have the LLM generate for us sample real estate listings

# %%
#setting the prompt template
messages = [
    (
        "system",
        "You are a real estate expert and has lot of knowledge in real estate listings.",
    ),
    ("human", f"""Create 10 sample data records for me in the following format. The format must be a csv, comma seperated adnand double quote seperate for each field.  
     The field and data types are in in the following format: 
     1/Neighborhood: [name], 
     2/ Price: [price], 
     3/ Bedrooms: [number], 
     4/ Bathrooms: [number], 
     5/ House Size: [sqft], 
     6/ House Description: [short description], 
     7/ Neighborhood Description: [short description]. 
     
     See the following sample for better idea 
     Neighborhood: Green Oaks, 
     Price: $800,000, 
     Bedrooms: 3, 
     Bathrooms: 2, 
     House Size: 2,000 sqft,  
     Description: Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as 
     solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. 
     The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. 
     Embrace sustainable living without compromising on style in this Green Oaks gem. ,
     Neighborhood Description: Green Oaks is a close-knit, environmentally-conscious 
     community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. 
     With easy access to public transportation and bike lanes, commuting is a breeze."""),
]

#invoking the model to generate syntehetic data
ai_msg = llm.invoke(messages)
ai_msg
print(ai_msg.content)
# Out:
# ```csv
# "Neighborhood","Price","Bedrooms","Bathrooms","House Size","House Description","Neighborhood Description"
# "Green Oaks","$800,000","3","2","2,000 sqft","Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features. Natural light floods the living spaces, highlighting the beautiful hardwood floors. The open-concept kitchen and dining area lead to a spacious backyard.","Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores and bike paths. Take a stroll through the nearby Green Oaks Park."
# "Meadowbrook","$650,000","4","2.5","2,500 sqft","Spacious family home in Meadowbrook with a large backyard perfect for entertaining. Features include a modern kitchen, updated bathrooms, and a finished basement.","Meadowbrook is a family-friendly neighborhood with excellent schools, parks, and community events. Enjoy a picnic by the lake or take the kids to the playground."
# "City Heights","$1,200,000","2","2","1,800 sqft","Modern condo in the heart of City Heights with stunning city views. Enjoy luxury living with high-end finishes, a rooftop pool, and a fitness center.","City Heights offers a vibrant urban lifestyle with easy access to restaurants, shops, and entertainment. Walk to work or explore the city's cultural attractions."
# "Oakwood","$725,000","3","2","2,200 sqft","Charming craftsman home in Oakwood with original details and modern updates. Features a cozy fireplace, a large front porch, and a private backyard.","Oakwood is a historic neighborhood with tree-lined streets and a strong sense of community. Enjoy local shops, restaurants, and annual festivals."
# "Pine Ridge","$550,000","3","1.5","1,900 sqft","Cozy cottage in Pine Ridge with a rustic charm and modern amenities. Features a wood-burning stove, a screened-in porch, and a large garden.","Pine Ridge is a peaceful, nature-filled neighborhood with hiking trails, lakes, and stunning mountain views. Escape the city and enjoy the tranquility of nature."
# "Sunset Valley","$950,000","4","3","3,000 sqft","Luxury home in Sunset Valley with breathtaking views of the valley. Features a gourmet kitchen, a swimming pool, and a private patio.","Sunset Valley offers a luxurious lifestyle with exclusive amenities, golf courses, and fine dining. Enjoy the stunning scenery and the tranquility of the valley."
# "Riverbend","$700,000","3","2","2,100 sqft","Updated ranch home in Riverbend with a modern kitchen and open floor plan. Features a large deck overlooking the river and a private dock.","Riverbend is a quiet, riverside community with access to boating, fishing, and kayaking. Enjoy the peaceful surroundings and the beauty of the river."
# "Maple Grove","$600,000","2","1","1,500 sqft","Charming bungalow in Maple Grove with a cozy atmosphere and modern updates. Features a fireplace, a sunroom, and a private backyard.","Maple Grove is a friendly neighborhood with a small-town feel and easy access to amenities. Enjoy local shops, restaurants, and community events."
# "Hillcrest","$1,100,000","5","3.5","3,500 sqft","Spacious estate in Hillcrest with panoramic views of the city. Features a grand foyer, a gourmet kitchen, and a luxurious master suite.","Hillcrest is an exclusive neighborhood with prestigious homes, private schools, and upscale amenities. Enjoy the best of city living with the privacy and tranquility of a gated community."
# "Willow Creek","$850,000","4","2.5","2,800 sqft","Modern farmhouse in Willow Creek with a rustic charm and modern amenities. Features a large front porch, a gourmet kitchen, and a spacious backyard.","Willow Creek is a peaceful, rural community with a strong sense of community and access to nature. Enjoy hiking trails, lakes, and the beauty of the countryside."
# ```

# %% [markdown]
# The above outputs are saved to a .csv file and then later opened in pandas for transformation

# %%
# Ensure the file 'listings.csv' exists in the correct directory
file_path = "listings.csv"
if os.path.exists(file_path):
	df = pd.read_csv(file_path)
else:
	print(f"File not found: {file_path}")
# Out:
# File not found: listings.csv

# %%
df.head()
# Out:
#       Neighborhood       Price  Bedrooms  Bathrooms  House Size  \
# 0       Green Oaks    $800,000         3        2.0  2,000 sqft
# 1      Meadowbrook    $650,000         4        2.5  2,500 sqft
# 2     City Heights  $1,200,000         2        2.0  1,800 sqft
# 3     Sunset Ridge    $725,000         3        2.0  2,200 sqft
# 4  Oakwood Estates    $950,000         5        3.0  3,000 sqft
#
#                                    House Description  \
# 0  Welcome to this eco-friendly oasis nestled in ...
# 1  Spacious family home in Meadowbrook with a lar...
# 2  Modern condo in City Heights with stunning cit...
# 3  Charming ranch-style home in Sunset Ridge with...
# 4  Executive home in Oakwood Estates with a luxur...
#
#                             Neighborhood Description  \
# 0  Green Oaks is a close-knit, environmentally-co...
# 1  Meadowbrook is a family-friendly neighborhood ...
# 2  City Heights offers a vibrant urban lifestyle ...
# 3  Sunset Ridge is a quiet, established neighborh...
# 4  Oakwood Estates is a prestigious community wit...
#
#                                 Combined Description
# 0  Welcome to this eco-friendly oasis nestled in ...
# 1  Spacious family home in Meadowbrook with a lar...
# 2  Modern condo in City Heights with stunning cit...
# 3  Charming ranch-style home in Sunset Ridge with...
# 4  Executive home in Oakwood Estates with a luxur...

# %%
# !pip install chromadb
# we combine all the descriptive and objective data into a single column.
df
df["Combined Description"] = df['House Description'] +  df['Neighborhood Description']
df
# Out:
#       Neighborhood       Price  Bedrooms  Bathrooms  House Size  \
# 0       Green Oaks    $800,000         3        2.0  2,000 sqft
# 1      Meadowbrook    $650,000         4        2.5  2,500 sqft
# 2     City Heights  $1,200,000         2        2.0  1,800 sqft
# 3     Sunset Ridge    $725,000         3        2.0  2,200 sqft
# 4  Oakwood Estates    $950,000         5        3.0  3,000 sqft
# 5        Riverbend    $580,000         2        1.5  1,500 sqft
# 6         Pinewood    $700,000         4        2.0  2,300 sqft
# 7        Hillcrest  $1,100,000         3        2.5  2,800 sqft
# 8      Harbor View    $875,000         4        3.0  2,600 sqft
# 9     Willow Creek    $620,000         3        2.0  1,900 sqft
#
#                                    House Description  \
# 0  Welcome to this eco-friendly oasis nestled in ...
# 1  Spacious family home in Meadowbrook with a lar...
# 2  Modern condo in City Heights with stunning cit...
# 3  Charming ranch-style home in Sunset Ridge with...
# 4  Executive home in Oakwood Estates with a luxur...
# 5  Cozy cottage in Riverbend with river views. Up...
# 6  Updated split-level home in Pinewood with a la...
# 7  Contemporary home in Hillcrest with panoramic ...
# 8  Beautiful home in Harbor View with water views...
# 9  Charming home in Willow Creek with a large bac...
#
#                             Neighborhood Description  \
# 0  Green Oaks is a close-knit, environmentally-co...
# 1  Meadowbrook is a family-friendly neighborhood ...
# 2  City Heights offers a vibrant urban lifestyle ...
# 3  Sunset Ridge is a quiet, established neighborh...
# 4  Oakwood Estates is a prestigious community wit...
# 5  Riverbend is a charming neighborhood with a sm...
# 6  Pinewood is a family-oriented neighborhood wit...
# 7  Hillcrest offers breathtaking views and a luxu...
# 8  Harbor View is a waterfront community with acc...
# 9  Willow Creek is a peaceful neighborhood with a...
#
#                                 Combined Description
# 0  Welcome to this eco-friendly oasis nestled in ...
# 1  Spacious family home in Meadowbrook with a lar...
# 2  Modern condo in City Heights with stunning cit...
# 3  Charming ranch-style home in Sunset Ridge with...
# 4  Executive home in Oakwood Estates with a luxur...
# 5  Cozy cottage in Riverbend with river views. Up...
# 6  Updated split-level home in Pinewood with a la...
# 7  Contemporary home in Hillcrest with panoramic ...
# 8  Beautiful home in Harbor View with water views...
# 9  Charming home in Willow Creek with a large bac...

# %%
# For semantic search to be possible, we will now initialize the chromadb store and
# save contents from the dataframe into the store.

# %%
from chromadb.config import Settings
import chromadb
collection_name = "real_estate"

# Initialize the ChromaDB client
client = chromadb.Client(Settings())

# List all collection names
existing_collections = client.list_collections()
print("Existing Collections:", existing_collections)
if collection_name in existing_collections:
    print(f"The collection '{collection_name}' exists.")
    client.delete_collection(collection_name)
    collection = client.create_collection("real_estate")
    print(f"The collection '{collection_name}' has been created.")
else:
    print(f"The collection '{collection_name}' does not exist.")
    collection = client.create_collection("real_estate")
    print(f"The collection '{collection_name}' has been created.")
# Out:
# Existing Collections: ['real_estate']
# The collection 'real_estate' exists.
# The collection 'real_estate' has been created.

# %%
# the google embedding and save all records from pandas dataframe in a loop into the chromadb store.

embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")
# Insert data into ChromaDB
for index, row in df.iterrows():
    # Create a unique ID for each listing
    listing_id = f"listing_{index}"
    
    # Generate embedding for the combined description
    embedding = embeddings.embed_query(row["Combined Description"])
    
    # Add the listing to ChromaDB
    collection.add(
        ids=[listing_id],
        embeddings=[embedding],
        metadatas=[{
            "Neighborhood": row["Neighborhood"],
            "Price": row["Price"],
            "Bedrooms": row["Bedrooms"],
            "Bathrooms": row["Bathrooms"],
            "House Size": row["House Size"],
            "House Description": row["House Description"],
            "Neighborhood Description": row["Neighborhood Description"]
        }]
    )

print("Data successfully inserted into ChromaDB!")
# Out:
# Data successfully inserted into ChromaDB!

# %%
# Step 6: Query Example 1 (Optional) to pull data from the chromadb store
# Example of semantic search in ChromaDB
# query = "ranch style"
query = "eco-friendly community with good schools"
query_embedding = embeddings.embed_query(query)

results = collection.query(
    query_embeddings=[query_embedding],
    n_results=2
)

for result_list in results["metadatas"]:
    for result in result_list:
        print(f"Neighborhood: {result['Neighborhood']}")
        print(f"Price: {result['Price']}")
        print(f"Bedrooms: {result['Bedrooms']}")
        print(f"Bathrooms: {result['Bathrooms']}")
        print(f"House Size: {result['House Size']}")
        print(f"Neighborhood Description: {result['Neighborhood Description']}")
        print(f"House Description: {result['House Description']}\n")
# Out:
# Neighborhood: Green Oaks
# Price: $800,000
# Bedrooms: 3
# Bathrooms: 2.0
# House Size: 2,000 sqft
# Neighborhood Description: Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores and community gardens.
# House Description: Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features.
#
# Neighborhood: Meadowbrook
# Price: $650,000
# Bedrooms: 4
# Bathrooms: 2.5
# House Size: 2,500 sqft
# Neighborhood Description: Meadowbrook is a family-friendly neighborhood with excellent schools, parks, and a community center.
# House Description: Spacious family home in Meadowbrook with a large backyard, perfect for entertaining. Features a modern kitchen and updated bathrooms.

# %%
# Step 6: Query Example 2 (Optional) to pull data from the chromadb store
query = "ranch style neighborhood"
query_embedding = embeddings.embed_query(query)

results = collection.query(
    query_embeddings=[query_embedding],
    n_results=2
)

for result_list in results["metadatas"]:
    for result in result_list:
        print(f"Neighborhood: {result['Neighborhood']}")
        print(f"Price: {result['Price']}")
        print(f"Bedrooms: {result['Bedrooms']}")
        print(f"Bathrooms: {result['Bathrooms']}")
        print(f"House Size: {result['House Size']}")
        print(f"Neighborhood Description: {result['Neighborhood Description']}")
        print(f"House Description: {result['House Description']}\n")
# Out:
# Neighborhood: Sunset Ridge
# Price: $725,000
# Bedrooms: 3
# Bathrooms: 2.0
# House Size: 2,200 sqft
# Neighborhood Description: Sunset Ridge is a quiet, established neighborhood with tree-lined streets and a peaceful atmosphere.
# House Description: Charming ranch-style home in Sunset Ridge with a large front porch and mature landscaping. Updated kitchen and spacious bedrooms.
#
# Neighborhood: Oakwood Estates
# Price: $950,000
# Bedrooms: 5
# Bathrooms: 3.0
# House Size: 3,000 sqft
# Neighborhood Description: Oakwood Estates is a prestigious community with large homes, manicured lawns, and a country club.
# House Description: Executive home in Oakwood Estates with a luxurious master suite and a finished basement.  Large backyard with a pool.

# %%
# Now we will create the static questions and answers for the real estate expert chatbot.
personal_questions = [   
                "How big do you want your house to be?" 
                "What are 3 most important things for you in choosing this property?", 
                "Which amenities would you like?", 
                "Which transportation options are important to you?",
                "How urban do you want your neighborhood to be?",   
            ]
personal_answers = [
    "A comfortable three-bedroom house with a spacious kitchen and a cozy living room.",
    "A quiet neighborhood, good local schools, and convenient shopping options.",
    "A backyard for gardening, a two-car garage, and a modern, energy-efficient heating system.",
    "Easy access to a reliable bus line, proximity to a major highway, and bike-friendly roads.",
    "A balance between suburban tranquility and access to urban amenities like restaurants and theaters."
]

# %%
# Pull the best real estate matches from ChromaDB and add to chat history
recommendation_query = "".join(personal_answers)  # Combine user answers into a single query
recommendation_query_embedding = embeddings.embed_query(recommendation_query)

best_matches = collection.query(
    query_embeddings=[recommendation_query_embedding],
    n_results=3
    # ,include_distances=True
)

# Sort results by distance and retrieve the results in desc order of the COSINE distance.

sorted_matches = []
for distance_list, metadata_list in zip(best_matches["distances"], best_matches["metadatas"]):
    for distance, metadata in zip(distance_list, metadata_list):
        sorted_matches.append((distance, metadata))

sorted_matches.sort(key=lambda x: x[0], reverse=True)

# Print the sorted results with distances
for distance, metadata in sorted_matches:
    combined_description = "  House Description: " + metadata['House Description'] + " Neighborhood Description: " + metadata['Neighborhood Description']
    combined_description = combined_description + "  Neighborhood: " + metadata['Neighborhood']
    combined_description = combined_description + "  Price: " + metadata['Price']
    combined_description = combined_description + "  Bedrooms: " + str(metadata['Bedrooms'])
    combined_description = combined_description + "  Bathrooms: " + str( metadata['Bathrooms'])
    combined_description = combined_description + "  House Size: " + metadata['House Size']
    # print(combined_description)
    
    messages = [
    (
        "system",
        """You are a real estate AI agent. Based on the following property data, provide:
            1. A short and attractive listing name for each property.
            2. An augmented description for each property, highlighting its unique features.
            
            Return the augmented descriptions and listing names for each property in a structured format on seperate lines:
            Listing name :
            Listing Description :
            
            At all times use only the data that is provided by the human.
            Do not make up any information. Do not hallucinate.""",
    ),
    ("human", {combined_description})
    ]
 
    llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2 #,     # other params...
    )
    llm_aug_msg = llm.invoke(messages)
    
    print(f"LLM Augmented Description: {llm_aug_msg.content}")
    print ("Additional Property Details")
    print ("++++++++++++++++++++++++++++++++++++++++++++++")
    # print(f"combined_description: {combined_description}")
    # print(f"Distance: {distance:.4f}")
    print(f"Neighborhood: {metadata['Neighborhood']}")
    print(f"Price: {metadata['Price']}")
    print(f"Bedrooms: {metadata['Bedrooms']}")
    print(f"Bathrooms: {metadata['Bathrooms']}")
    print(f"House Size: {metadata['House Size']}\n")
    # print(f"Neighborhood Description: {metadata['Neighborhood Description']}")
    # print(f"House Description: {metadata['House Description']}\n")
# Out:
# LLM Augmented Description: Listing name : Charming Sunset Ridge Ranch
# Listing Description : This charming 3-bedroom, 2-bathroom ranch-style home in the peaceful Sunset Ridge neighborhood boasts 2,200 sqft of comfortable living space.  Enjoy a large front porch, mature landscaping, and an updated kitchen.  The spacious bedrooms and quiet, tree-lined streets make this the perfect place to call home.
#
# Additional Property Details
# ++++++++++++++++++++++++++++++++++++++++++++++
# Neighborhood: Sunset Ridge
# Price: $725,000
# Bedrooms: 3
# Bathrooms: 2.0
# House Size: 2,200 sqft
#
# LLM Augmented Description: Listing name : Willow Creek Retreat
# Listing Description : Charming 3-bedroom, 2-bathroom home in the peaceful Willow Creek neighborhood. This 1,900 sqft home boasts a large backyard, perfect for outdoor enjoyment, and a screened porch for relaxing evenings.  Enjoy easy access to parks and walking trails, and be part of a strong sense of community. Priced at $620,000.
#
# Additional Property Details
# ++++++++++++++++++++++++++++++++++++++++++++++
# Neighborhood: Willow Creek
# Price: $620,000
# Bedrooms: 3
# Bathrooms: 2.0
# House Size: 1,900 sqft
#
# LLM Augmented Description: Listing name : Meadowbrook Family Oasis
# Listing Description : This spacious 2,500 sqft family home boasts 4 bedrooms and 2.5 bathrooms, perfect for comfortable living.  The modern kitchen and updated bathrooms add a touch of luxury.  Enjoy the large backyard, ideal for entertaining, all within the family-friendly Meadowbrook neighborhood, known for its excellent schools, parks, and community center. Priced at $650,000.
#
# Additional Property Details
# ++++++++++++++++++++++++++++++++++++++++++++++
# Neighborhood: Meadowbrook
# Price: $650,000
# Bedrooms: 4
# Bathrooms: 2.5
# House Size: 2,500 sqft
