# %%
#!pip install google-generativeai
# !pip install faster-whisper
# !pip install numpy
# !pip install openai
# !pip install pyaudio
# Out:
# ...
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\rajes\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~yarrow (C:\Users\rajes\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\rajes\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~yarrow (C:\Users\rajes\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\rajes\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~yarrow (C:\Users\rajes\anaconda3\Lib\site-packages)
