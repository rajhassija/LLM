# %%
# !pip install -U langchain-google-genai
import os
# export GOOGLE_API_KEY='AIzaSyDG8Hh3JEAwWKdXz5j6yjJL2GKOlUy_7es'
os.environ['GOOGLE_API_KEY'] = 'AIzaSyDG8Hh3JEAwWKdXz5j6yjJL2GKOlUy_7es'

from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-1.5-pro-001")
llm.invoke("Sing a ballad of LangChain.")
# Out:
# AIMessage(content="(Verse 1)\nGather 'round ye coders bold, and hear my tale unfold,\nOf LangChain, a library, with powers yet untold.\nIt chains together language models, strong and vast,\nTo build applications grand, that forever will outlast.\n\n(Verse 2)\nNo longer shall you toil and sweat, with prompts and outputs set,\nLangChain weaves them all with grace, a tapestry of text.\nFrom chatbots bright and full of cheer, to agents that adhere,\nTo complex tasks and queries deep, LangChain's magic, it will seep.\n\n(Verse 3)\nWith modules for every need, from memory to prompt indeed,\nYou'll craft creations wondrous strange, upon this digital stage.\nConnect your models, one and all, let them answer every call,\nWith chains of thought and reasoning, that rise above the banal.\n\n(Verse 4)\nSo raise a glass to LangChain high, a toast beneath the coding sky,\nMay its potential never cease, and bring our projects swift release.\nFrom simple scripts to systems grand, it empowers every ha
# ...

# %%
import getpass
import os
os.environ['GOOGLE_API_KEY'] = 'AIzaSyDG8Hh3JEAwWKdXz5j6yjJL2GKOlUy_7es' ## gemini 1.5 pro key

# if "GOOGLE_API_KEY" not in os.environ:
#     os.environ["GOOGLE_API_KEY"] = getpass.getpass("AIzaSyDG8Hh3JEAwWKdXz5j6yjJL2GKOlUy_7es")

# %%
# !pip install -qU langchain-google-genai
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-openai 0.2.0 requires openai<2.0.0,>=1.40.0, but you have openai 0.28.0 which is incompatible.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-pro",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2 #,     # other params...
)

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to French. Translate the user sentence.",
    ),
    ("human", "I love biking."),
]
ai_msg = llm.invoke(messages)
ai_msg
print(ai_msg.content)
# Out:
# J'adore faire du vélo.

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")
vector = embeddings.embed_query("hello, world!")
vector[:5]
# Out:
# [0.05168594419956207,
#  -0.030764883384108543,
#  -0.03062233328819275,
#  -0.02802734263241291,
#  0.01813093200325966]

# %%
vectors = embeddings.embed_documents(
    [
        "Today is Monday",
        "Today is Tuesday",
        "Today is April Fools day",
    ]
)
len(vectors), len(vectors[0])
# Out:
# (3, 768)
