# %%
# move this file outside the directory and run the code to test
from rag_framework import RAGFramework


if __name__ == "__main__":
    rag = RAGFramework()
    rag.run("What is AI?")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from rag_framework import RAGFramework
#       4 if __name__ == "__main__":
#       5     rag = RAGFramework()
#
# ModuleNotFoundError: No module named 'rag_framework'
